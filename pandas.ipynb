# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')
df.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.iloc[:3, :5]
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test preparation course
# 0                    none
# 1               completed
# 2                    none

# %%
df.iloc[[0,7,15], [0,1,2]]
# Out:
#     gender race/ethnicity parental level of education
# 0   female        group B           bachelor's degree
# 7     male        group B                some college
# 15  female        group C            some high school

# %%
type(df.iloc[:, 0])
# Out:
# pandas.core.series.Series

# %%
srs = pd.Series([1,2,3], index=['Bob', 'John', 'Mike'])
srs1 = pd.Series([22,33,44], index=['Bob', 'John', 'Mike'])
pd.DataFrame({'col1': srs, 'col2': srs1})
# Out:
#       col1  col2
# Bob      1    22
# John     2    33
# Mike     3    44

# %%
df.loc[:7] # предоставляет доступ к строкам по лейблу(названию индекса)
df.iloc[:7] # предоставляет доступ к строкам по индексу
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
df.size
# Out:
# 8000

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df.select_dtypes(object)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course
# 0                      none
# 1                 completed
# 2                      none
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df.dtypes.value_counts()
# Out:
# object    5
# int64     3
# dtype: int64

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.dtypes.value_counts()
# Out:
# object    5
# int64     3
# dtype: int64

# %% [markdown]
# ## Фильтрация данных

# %%
df[df.gender == 'female']
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 993  female        group D           bachelor's degree  free/reduced
# 995  female        group E             master's degree      standard
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.loc[(df['math score'] >= df['math score'].mean()) & (df['gender'] == 'female')]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# ..      ...            ...                         ...           ...
# 984  female        group C            some high school      standard
# 989  female        group D                some college  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df['lunch'].value_counts(dropna=False, normalize=True)
# Out:
# standard        0.645
# free/reduced    0.355
# Name: lunch, dtype: float64

# %%
(df.lunch == 'free/reduced').mean()
# Out:
# 0.355

# %%
df.groupby('lunch')[['math score', 'reading score', 'writing score']].agg(['mean', 'std'])
# Out:
#              math score            reading score            writing score  \
#                    mean        std          mean        std          mean
# lunch
# free/reduced  58.921127  15.159956     64.653521  14.895339     63.022535
# standard      70.034109  13.653501     71.654264  13.830602     70.823256
#
#
#                     std
# lunch
# free/reduced  15.433823
# standard      14.339487

# %%
df.groupby('lunch').describe()
# Out:
#              math score                                                       \
#                   count       mean        std   min   25%   50%   75%    max
# lunch
# free/reduced      355.0  58.921127  15.159956   0.0  49.0  60.0  69.0  100.0
# standard          645.0  70.034109  13.653501  19.0  61.0  69.0  80.0  100.0
#
#              reading score             ...              writing score  \
#                      count       mean  ...   75%    max         count
# lunch                                  ...
# free/reduced         355.0  64.653521  ...  75.0  100.0         355.0
# standard             645.0  71.654264  ...  82.0  100.0         645.0
#
#
#                    mean        std   min   25%   50%   75%    max
# lunch
# free/reduced  63.022535  15.433823  10.0  53.0  64.0  74.0  100.0
# standard      70.823256  14.339487  22.0  62.0  72.0  81.0  100.0
#
# [2 rows x 24 columns]

# %%
df.columns = [col.replace(' ', '_') for col in df.columns]
df
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
df.query('writing_score > 74 & gender == "female"')
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 15   female        group C            some high school      standard
# ..      ...            ...                         ...           ...
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 995  female        group E             master's degree      standard
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score
# ...

# %%
df.filter(like='score')
# Out:
#      math_score  reading_score  writing_score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %% [markdown]
# ## Groupby. Aggregate

# %%
df.groupby('gender').mean()
# Out:
#         math_score  reading_score  writing_score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
df.groupby('gender', as_index=False).agg({'math_score':['count', 'mean', 'std']})
# Out:
#    gender math_score
#                count       mean        std
# 0  female        518  63.633205  15.491453
# 1    male        482  68.728216  14.356277

# %%
df.groupby('gender', as_index=False).agg({'math_score': 'mean', 'writing_score': 'mean'})
# Out:
#    gender  math_score  writing_score
# 0  female   63.633205      72.467181
# 1    male   68.728216      63.311203

# %%
df.groupby(['gender', 'race/ethnicity'], as_index=False).agg(['count', 'mean', 'std'])
# Out:
#                       math_score                       reading_score  \
#                            count       mean        std         count
# gender race/ethnicity
# female group A                36  58.527778  14.157252            36
#        group B               104  61.403846  16.256750           104
#        group C               180  62.033333  15.007224           180
#        group D               129  65.248062  14.174157           129
#        group E                69  70.811594  16.269129            69
# male   group A                53  63.735849  14.520742            53
#        group B                86  65.930233  14.156928            86
#        group C               139  67.611511  14.090037           139
#        group D               133  69.413534  13.094139           133
#        group E                71  76.746479  14.298570            71
#
#                                             writing_score             \
# ...

# %%
df.groupby(['gender', 'race/ethnicity']).math_score.nunique()
# Out:
# gender  race/ethnicity
# female  group A           29
#         group B           51
#         group C           59
#         group D           53
#         group E           44
# male    group A           38
#         group B           43
#         group C           56
#         group D           49
#         group E           38
# Name: math_score, dtype: int64

# %%
df.sort_values(['gender', 'math_score'], ascending=False).groupby('gender').head()
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 114  female        group E           bachelor's degree      standard
# 263  female        group E                 high school      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 149               completed         100            100             93
# ...

# %%
df['total_score'] = df.filter(like='score').sum(1)
df
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
df.assign(total_score_log = np.log(df.total_score)).head() #возвращает новый dataframe, не изменяя оригинальный
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score  total_score_log
# 0          218         5.384495
# 1          247         5.509388
# 2          278         5.627621
# ...

# %%
df.head()
# Out:
#    gender race/ethnicity parental_level_of_education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test_preparation_course  math_score  reading_score  writing_score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
#
#    total_score
# 0          218
# 1          247
# 2          278
# 3          148
# 4          229

# %%
df_dota = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv')
df_dota.head()
# Out:
#    Unnamed: 0 attack_type  id  legs  localized_name  \
# 0           0       Melee   1     2       Anti-Mage
# 1           1       Melee   2     2             Axe
# 2           2      Ranged   3     4            Bane
# 3           3       Melee   4     2     Bloodseeker
# 4           4      Ranged   5     2  Crystal Maiden
#
#                            name primary_attr  \
# 0        npc_dota_hero_antimage          agi
# 1             npc_dota_hero_axe          str
# 2            npc_dota_hero_bane          int
# 3     npc_dota_hero_bloodseeker          agi
# 4  npc_dota_hero_crystal_maiden          int
#
#                                                roles
# 0                       ['Carry', 'Escape', 'Nuker']
# 1    ['Initiator', 'Durable', 'Disabler', 'Jungler']
# 2        ['Support', 'Disabler', 'Nuker', 'Durable']
# 3  ['Carry', 'Disabler', 'Jungler', 'Nuker', 'Ini...
# 4        ['Support', 'Disabler', 'Nuker', 'Jungler']

# %%
df_dota.groupby('legs')['legs'].agg(['count'])
# Out:
#       count
# legs
# 0        11
# 2        95
# 4         7
# 6         3
# 8         1

# %%
df_dota.legs.value_counts()
# Out:
# 2    95
# 0    11
# 4     7
# 6     3
# 8     1
# Name: legs, dtype: int64

# %%
df_dota.groupby('legs').size()
# Out:
# legs
# 0    11
# 2    95
# 4     7
# 6     3
# 8     1
# dtype: int64

# %%
df_test = pd.read_csv('https://stepik.org/media/attachments/course/4852/accountancy.csv')
df_test.head()
# Out:
#    Unnamed: 0 Executor Type  Salary
# 0           0     Pupa    D      63
# 1           1     Pupa    A     158
# 2           2     Pupa    D     194
# 3           3     Pupa    E     109
# 4           4    Loopa    E     184

# %%
df_test.groupby(['Type', 'Executor'])['Salary'].agg(['count', 'mean'])
# Out:
#                count        mean
# Type Executor
# A    Loopa         1   58.000000
#      Pupa          6  160.833333
# B    Loopa         6  145.166667
#      Pupa          1   77.000000
# C    Loopa         6  154.333333
#      Pupa          2   74.500000
# D    Loopa         7  137.714286
#      Pupa          4  146.500000
# E    Loopa         6  164.000000
#      Pupa          5  131.200000
# F    Loopa         2  238.000000
#      Pupa          4  136.250000

# %%
df_test.groupby(['Type', 'Executor'])[['Salary']].mean() \
    .sort_values(['Type', 'Salary'], ascending=[True, False]) \
    .groupby('Type').head(1)
# Out:
#                    Salary
# Type Executor
# A    Pupa      160.833333
# B    Loopa     145.166667
# C    Loopa     154.333333
# D    Pupa      146.500000
# E    Loopa     164.000000
# F    Loopa     238.000000

# %%
df_dota.groupby(['attack_type', 'primary_attr']).size()
# Out:
# attack_type  primary_attr
# Melee        agi             19
#              int              2
#              str             35
# Ranged       agi             18
#              int             40
#              str              3
# dtype: int64

# %%
df_dota.filter(items=['attack_type', 'primary_attr']).mode()
# Out:
#   attack_type primary_attr
# 0      Ranged          int

# %%
df_kelp = pd.read_csv('http://stepik.org/media/attachments/course/4852/algae.csv')
df_kelp
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %%
df_kelp.groupby('genus').mean()
# Out:
#               sucrose    alanin   citrate   glucose  oleic_acid
# genus
# Ascophyllum  6.825467  0.875429  5.253527  3.414961    2.432526
# Cladophora   4.008792  3.997055  5.288311  2.800276    2.263472
# Fucus        4.355112  3.566411  4.214878  2.814803    3.367647
# Palmaria     0.704580  3.176440  5.573905  3.242090    2.245538
# Saccharina   4.183596  3.524207  3.346710  4.980594    4.487252

# %%
df_kelp[df_kelp.genus=='Fucus'].describe()
# Out:
#         sucrose    alanin   citrate   glucose  oleic_acid
# count  3.000000  3.000000  3.000000  3.000000    3.000000
# mean   4.355112  3.566411  4.214878  2.814803    3.367647
# std    2.110570  3.149943  2.691679  0.713559    3.050376
# min    3.001472  0.346431  1.216767  2.272724    0.304573
# 25%    3.139171  2.028965  3.110515  2.410591    1.848888
# 50%    3.276870  3.711498  5.004262  2.548459    3.393203
# 75%    5.031933  5.176401  5.713934  3.085842    4.899184
# max    6.786996  6.641303  6.423606  3.623225    6.405165

# %%
df_kelp.query('genus=="Fucus"')[['alanin']].agg(['min', 'mean', 'max'])
# Out:
#         alanin
# min   0.346431
# mean  3.566411
# max   6.641303

# %%
df_kelp.groupby('group')[['sucrose', 'citrate']].agg(['count', 'mean', 'std'])
# Out:
#       sucrose                     citrate
#         count      mean       std   count      mean       std
# group
# brown       6  4.709666  2.336471       6  4.098597  2.338577
# green       3  4.008792  1.634817       3  5.288311  1.987489
# red         1  0.704580       NaN       1  5.573905       NaN

# %%
df_kelp.groupby('group') \
    .agg({'citrate': 'var', 'sucrose': lambda x: x.max() - x.min(), 'glucose': 'count'}) \
    .round(2)
# Out:
#        citrate  sucrose  glucose
# group
# brown     5.47     5.19        6
# green     3.95     3.26        3
# red        NaN     0.00        1

# %% [markdown]
# ## Визуализация

# %%
df.math_score.hist()
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='math_score', y='reading_score')
# Out:
# <AxesSubplot:xlabel='math_score', ylabel='reading_score'>

# %%
sns.lmplot(x='math_score', y='reading_score', hue='gender', data=df, fit_reg=False)

# %%
df_income = pd.read_csv('https://stepik.org/media/attachments/course/4852/income.csv')
df_income
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
df_income.plot()
# Out:
# <AxesSubplot:>

# %%
df_test = pd.read_csv('dataset_209770_6.txt', sep=' ')
df_test
# Out:
#               x            y
# 0   1306.165175   996.756352
# 1   1205.828762   804.094833
# 2   1499.773713  1193.586365
# 3    302.281238   507.022829
# 4     93.771236  1500.336221
# ..          ...          ...
# 95  1207.862659   806.652165
# 96  1201.643737   796.233190
# 97   300.258299   504.301831
# 98  1393.218040   595.574214
# 99  1006.580215   209.141870
#
# [100 rows x 2 columns]

# %%
df_test.plot.scatter(x='x', y='y')
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
df_test = pd.read_csv('https://stepik.org/media/attachments/course/4852/genome_matrix.csv')
df_test = df_test.set_index('Unnamed: 0')
df_test
# Out:
#             species0  species1  species2  species3  species4
# Unnamed: 0
# species0    0.536029  0.920292  0.679708  0.840606  0.430842
# species1    0.920292  0.862417  0.887593  0.769754  0.203214
# species2    0.679708  0.887593  0.595156  0.003435  0.096052
# species3    0.840606  0.769754  0.003435  0.458870  0.029251
# species4    0.430842  0.203214  0.096052  0.029251  0.642109

# %%
ax = sns.heatmap(df_test, cmap='viridis')
ax.xaxis.set_ticks_position('top')
ax.xaxis.set_tick_params(rotation=90)

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv')
df
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
df['roles_total'] = df.roles.str.count(',') + 1
sns.countplot(x=df['roles_total'])
# Out:
# <AxesSubplot:xlabel='roles_total', ylabel='count'>

# %%
df.roles_total.mode()
# Out:
# 0    4
# dtype: int64

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/iris.csv', index_col=0)
df
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
sns.pairplot(df, diag_kind='kde', vars=df.columns[:-1])

# %%
df.iloc[:,:-1]
# Out:
#      sepal length  sepal width  petal length  petal width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
sns.kdeplot(data=df.iloc[:,:-1], shade=True)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.displot(data=df.iloc[:,:-1], kind='kde')

# %%
sns.violinplot(data=df['petal length'], orient='v')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(df.iloc[:,:-1].corr(), cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df, hue='species')

# %%
my_data = pd.DataFrame({
    'type': ['A', 'A', 'B', 'B'],
    'value': [10, 14, 12, 23]})
my_data
# Out:
#   type  value
# 0    A     10
# 1    A     14
# 2    B     12
# 3    B     23

# %%
df
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
df.drop(df.iloc[[0,5]].index).iloc[:, [1,3]]
# Out:
#      sepal width  petal width
# 1            3.0          0.2
# 2            3.2          0.2
# 3            3.1          0.2
# 4            3.6          0.2
# 6            3.4          0.3
# ..           ...          ...
# 145          3.0          2.3
# 146          2.5          1.9
# 147          3.0          2.0
# 148          3.4          2.3
# 149          3.0          1.8
#
# [148 rows x 2 columns]

# %%
df.drop([0,4]).iloc[:, [1,3]]
# Out:
#      sepal width  petal width
# 1            3.0          0.2
# 2            3.2          0.2
# 3            3.1          0.2
# 5            3.9          0.4
# 6            3.4          0.3
# ..           ...          ...
# 145          3.0          2.3
# 146          2.5          1.9
# 147          3.0          2.0
# 148          3.4          2.3
# 149          3.0          1.8
#
# [148 rows x 2 columns]

# %%
df.drop(df.iloc[:5].index)
# Out:
#      sepal length  sepal width  petal length  petal width  species
# 5             5.4          3.9           1.7          0.4        0
# 6             4.6          3.4           1.4          0.3        0
# 7             5.0          3.4           1.5          0.2        0
# 8             4.4          2.9           1.4          0.2        0
# 9             4.9          3.1           1.5          0.1        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [145 rows x 5 columns]

# %%
df.columns = [col.replace(' ', '_') for col in df.columns]
df.query('sepal_length > 5 & sepal_width < 3 & petal_width < 1.3')
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  species
# 62           6.0          2.2           4.0          1.0        1
# 67           5.8          2.7           4.1          1.0        1
# 69           5.6          2.5           3.9          1.1        1
# 73           6.1          2.8           4.7          1.2        1
# 79           5.7          2.6           3.5          1.0        1
# 80           5.5          2.4           3.8          1.1        1
# 81           5.5          2.4           3.7          1.0        1
# 82           5.8          2.7           3.9          1.2        1
# 90           5.5          2.6           4.4          1.2        1
# 92           5.8          2.6           4.0          1.2        1
# 98           5.1          2.5           3.0          1.1        1

# %%
df[(df.sepal_length > 5) & (df.sepal_width < 3) & (df.petal_width < 1.3)]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  species
# 62           6.0          2.2           4.0          1.0        1
# 67           5.8          2.7           4.1          1.0        1
# 69           5.6          2.5           3.9          1.1        1
# 73           6.1          2.8           4.7          1.2        1
# 79           5.7          2.6           3.5          1.0        1
# 80           5.5          2.4           3.8          1.1        1
# 81           5.5          2.4           3.7          1.0        1
# 82           5.8          2.7           3.9          1.2        1
# 90           5.5          2.6           4.4          1.2        1
# 92           5.8          2.6           4.0          1.2        1
# 98           5.1          2.5           3.0          1.1        1

# %%
# %timeit df[(df.sepal_length > 5) & (df.sepal_width < 3) & (df.petal_width < 1.3)]
# %timeit df.query('sepal_length > 5 & sepal_width < 3 & petal_width < 1.3')
# Out:
# 573 µs ± 7.62 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
# 1.51 ms ± 14.4 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
df.assign(sepal_sum = df.sepal_width + df.sepal_length)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species  sepal_sum
# 0             5.1          3.5           1.4          0.2        0        8.6
# 1             4.9          3.0           1.4          0.2        0        7.9
# 2             4.7          3.2           1.3          0.2        0        7.9
# 3             4.6          3.1           1.5          0.2        0        7.7
# 4             5.0          3.6           1.4          0.2        0        8.6
# ..            ...          ...           ...          ...      ...        ...
# 145           6.7          3.0           5.2          2.3        2        9.7
# 146           6.3          2.5           5.0          1.9        2        8.8
# 147           6.5          3.0           5.2          2.0        2        9.5
# 148           6.2          3.4           5.4          2.3        2        9.6
# 149           5.9          3.0           5.1          1.8        2        8.9
#
# [150 rows x 6 columns]

# %%
df.assign(log = np.log(df.sepal_length))
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species       log
# 0             5.1          3.5           1.4          0.2        0  1.629241
# 1             4.9          3.0           1.4          0.2        0  1.589235
# 2             4.7          3.2           1.3          0.2        0  1.547563
# 3             4.6          3.1           1.5          0.2        0  1.526056
# 4             5.0          3.6           1.4          0.2        0  1.609438
# ..            ...          ...           ...          ...      ...       ...
# 145           6.7          3.0           5.2          2.3        2  1.902108
# 146           6.3          2.5           5.0          1.9        2  1.840550
# 147           6.5          3.0           5.2          2.0        2  1.871802
# 148           6.2          3.4           5.4          2.3        2  1.824549
# 149           5.9          3.0           5.1          1.8        2  1.774952
#
# [150 rows x 6 columns]

# %%
df.rename(columns={'asd': 'sepal_length'}, inplace=True)
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat.csv')
df
# Out:
#      V1    V2 V3   V4
# 0     2  13.0  B  1.0
# 1    -1   7.0  B  1.0
# 2     0  11.0  A  0.0
# 3     2  11.0  A  2.0
# 4     0  10.0  B -1.0
# ..   ..   ... ..  ...
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 497  -1  11.0  B  2.0
# 498   1  11.0  A  2.0
# 499   0   8.0  B  1.0
#
# [500 rows x 4 columns]

# %%
df.rename(columns={
    'V1': 'session_value',
    'V2': 'group',
    'V3': 'time',
    'V4': 'n_users'},
    inplace=True)
df
# Out:
#      session_value  group time  n_users
# 0                2   13.0    B      1.0
# 1               -1    7.0    B      1.0
# 2                0   11.0    A      0.0
# 3                2   11.0    A      2.0
# 4                0   10.0    B     -1.0
# ..             ...    ...  ...      ...
# 495              1    8.0    A     -1.0
# 496              3    8.0    A      1.0
# 497             -1   11.0    B      2.0
# 498              1   11.0    A      2.0
# 499              0    8.0    B      1.0
#
# [500 rows x 4 columns]

# %%
df.isnull().mean()
# Out:
# session_value    0.0
# group            0.0
# time             0.0
# n_users          0.0
# dtype: float64

# %%
df.session_value.fillna(0)
# Out:
# 0      2
# 1     -1
# 2      0
# 3      2
# 4      0
#       ..
# 495    1
# 496    3
# 497   -1
# 498    1
# 499    0
# Name: session_value, Length: 500, dtype: int64

# %%
df.n_users[df.n_users > 0].median()
# Out:
# 1.0

# %%
df.size()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-531-5098ab42f864> in <module>
# ----> 1 df.size()
#
# TypeError: 'numpy.int64' object is not callable

# %%
df.loc[df.n_users < 0, 'n_users'] = df.n_users[df.n_users > 0].median()
df['nulls'] = [np.nan for i in range(len(df))]
df
# Out:
#      session_value  group time  n_users  nulls
# 0                2   13.0    B      1.0    NaN
# 1               -1    7.0    B      1.0    NaN
# 2                0   11.0    A      0.0    NaN
# 3                2   11.0    A      2.0    NaN
# 4                0   10.0    B      1.0    NaN
# ..             ...    ...  ...      ...    ...
# 495              1    8.0    A      1.0    NaN
# 496              3    8.0    A      1.0    NaN
# 497             -1   11.0    B      2.0    NaN
# 498              1   11.0    A      2.0    NaN
# 499              0    8.0    B      1.0    NaN
#
# [500 rows x 5 columns]

# %%
df.nulls = df.nulls.fillna(0)
df
# Out:
#      session_value  group time  n_users  nulls
# 0                2   13.0    B      1.0    0.0
# 1               -1    7.0    B      1.0    0.0
# 2                0   11.0    A      0.0    0.0
# 3                2   11.0    A      2.0    0.0
# 4                0   10.0    B      1.0    0.0
# ..             ...    ...  ...      ...    ...
# 495              1    8.0    A      1.0    0.0
# 496              3    8.0    A      1.0    0.0
# 497             -1   11.0    B      2.0    0.0
# 498              1   11.0    A      2.0    0.0
# 499              0    8.0    B      1.0    0.0
#
# [500 rows x 5 columns]

# %%
df = pd.read_csv('https://stepik.org/media/attachments/course/4852/my_stat_1.csv')
df
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            NaN    11     A       -1
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9
# 5            3.0     8     A        8
# 6            NaN    11     B        5
# 7            0.0     9     A        4
# 8            0.0     8     B      -11
# 9            0.0     9     A      -20

# %%
df.session_value = df.session_value.fillna(0)
df
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B        9
# 1            0.0    11     A       -1
# 2            1.0     8     A        1
# 3            2.0     9     B        3
# 4            2.0    10     B        9
# 5            3.0     8     A        8
# 6            0.0    11     B        5
# 7            0.0     9     A        4
# 8            0.0     8     B      -11
# 9            0.0     9     A      -20

# %%
df.n_users[df.n_users >= 0.0].median(0)
# Out:
# 5.0

# %%
df.n_users[df.n_users >= 0].median()
df.loc[df.n_users < 0, 'n_users'] = 0
df
# Out:
#    session_value  time group  n_users
# 0            0.0    12     B      9.0
# 1            0.0    11     A      0.0
# 2            1.0     8     A      1.0
# 3            2.0     9     B      3.0
# 4            2.0    10     B      9.0
# 5            3.0     8     A      8.0
# 6            0.0    11     B      5.0
# 7            0.0     9     A      4.0
# 8            0.0     8     B      0.0
# 9            0.0     9     A      0.0

# %%
1002/3
# Out:
# 334.0

# %%
df.groupby(['group'], as_index=False).agg(mean_session_value=('session_value','mean'))
# Out:
#   group  mean_session_value
# 0     A                 1.0
# 1     B                 1.0

# %%
t=df.groupby(['group'], as_index=False)['session_value'].agg('mean')
t.rename(columns={'session_value': 'mean'}, inplace=True)
t
# Out:
#   group  mean
# 0     A   1.0
# 1     B   1.0

# %%
df.groupby("group",as_index=False).session_value.agg({'mean_session_value':'mean'})
# Out:
#   group  mean_session_value
# 0     A                 1.0
# 1     B                 1.0
